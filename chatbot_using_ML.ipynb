# %%
import nltk
import random
import numpy as np
import pandas as pd
import string
import warnings
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.linear_model import LogisticRegression

nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
data= {
    "text" :["hello","hai","hi","good morning","good night","hey","how are you","see you","what is your name","what do you do","what is the technique used to build you","who are you","thank you","see you bye","iam going","bye bye","so good","see you later","nice to see you"],
    "intent":["greeting","greeting","greeting","greeting","greeting","greeting","greeting","greeting","about","about","about","about","farewell","farewell","farewell","farewell","gratitude","gratitude","gratitude"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                        text     intent
# 0                                     hello   greeting
# 1                                       hai   greeting
# 2                                        hi   greeting
# 3                              good morning   greeting
# 4                                good night   greeting
# 5                                       hey   greeting
# 6                               how are you   greeting
# 7                                   see you   greeting
# 8                         what is your name      about
# 9                            what do you do      about
# 10  what is the technique used to build you      about
# 11                              who are you      about
# 12                                thank you   farewell
# 13                              see you bye   farewell
# 14                                iam going   farewell
# 15                                  bye bye   farewell
# ...

# %%
def preprocess(data):
  tokens=word_tokenize(data.lower())
  tokens = [word for word in tokens if word.isalnum()]
  return " ".join(tokens)
df["clean_text"]= df["text"].apply(preprocess)

# %%
df
# Out:
#                                        text     intent  \
# 0                                     hello   greeting
# 1                                       hai   greeting
# 2                                        hi   greeting
# 3                              good morning   greeting
# 4                                good night   greeting
# 5                                       hey   greeting
# 6                               how are you   greeting
# 7                                   see you   greeting
# 8                         what is your name      about
# 9                            what do you do      about
# 10  what is the technique used to build you      about
# 11                              who are you      about
# 12                                thank you   farewell
# 13                              see you bye   farewell
# 14                                iam going   farewell
# 15                                  bye bye   farewell
# ...

# %%
vectorizer = TfidfVectorizer()
x_train_tfidf = vectorizer.fit_transform(df["clean_text"])

# %%
model = LogisticRegression()
model.fit(x_train_tfidf, df["intent"])
# Out:
# LogisticRegression()

# %%
model.predict(x_train_tfidf)
# Out:
# array(['greeting', 'greeting', 'greeting', 'greeting', 'greeting',
#        'greeting', 'greeting', 'greeting', 'about', 'about', 'about',
#        'greeting', 'farewell', 'farewell', 'farewell', 'farewell',
#        'greeting', 'greeting', 'greeting'], dtype=object)

# %%
def chatbot_response(user_input):
  user_input = preprocess(user_input)
  user_tfidf = vectorizer.transform([user_input])

  similarity_score = cosine_similarity(user_tfidf,x_train_tfidf)
  max_similarity = np.max(similarity_score)
  #best_match_index = np.argmax(similarity_score)
  print(max_similarity)


  if max_similarity < 0.2:
    return "sorry I  didn't understand that."
#predict intent using logistic reegression
  predicted_intent = model.predict(user_tfidf)[0]


  responses = {
      "greeting": "hello, how can i help you",
      "about" : "iam a chatbot build using logistic regression and cosine similarity!",
      "farewell" : "goodbye have a great day",
      "gratitude":"You'r welcome",
  }

  return responses.get(predicted_intent,"sorry I didn't understand that.")

# %%
while True:
  user_input = input("you : ")
  if user_input.lower() in ["bye", "quit"]:
    print("chatbot: goodbye")
    break
  print("chatbot: ",chatbot_response(user_input))
# Out:
# you : 	what is the technique used to build you
# 1.0
# chatbot:  iam a chatbot build using logistic regression and cosine similarity!
# you : hai
# 1.0
# chatbot:  hello, how can i help you
# you : hello
# 1.0
# chatbot:  hello, how can i help you
# you : iam going
# 1.0000000000000002
# chatbot:  goodbye have a great day
# you : bye
# chatbot: goodbye
